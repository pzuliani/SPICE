# %%
using Plots
pyplot()
pyplot()
upscale = 5 #8x upscaling in resolution
fntsm = Plots.font("cmr10", 10.0*upscale)
fntsm2 = Plots.font("serif", 10.0*upscale)
fntlg = Plots.font("serif", 14.0*upscale)
fntlg2 = Plots.font("cmr10", 14.0*upscale)
default(titlefont=fntlg, guidefont=fntlg2, tickfont=fntsm, legendfont=fntsm2)
default(dpi=350) #Only for PyPlot - presently broken

# %%
using DataFrames
#df = readtable("flow-data-gardner.txt",separator='\t',header=false)
df = readtable("iptg")
# df=readtable("data.csv",header=true)
# df=df[df[:inducer].=="atc",:]
# df=df[df[:times].!==24,:]
# df=df[df[:repeats].==1,:]
# df[:, filter(x -> (x in [:times,:GFP_H,:mCherry_H]), names(df))]
# Out:
# 40731×3 DataFrames.DataFrame
# │ Row   │ Times │ X1      │ X2        │
# ├───────┼───────┼─────────┼───────────┤
# │ 1     │ 0.5   │ 4308.0  │ 1.76546e5 │
# │ 2     │ 0.5   │ 4840.0  │ 9.54229e5 │
# │ 3     │ 0.5   │ 2118.0  │ 1.14923e5 │
# │ 4     │ 0.5   │ 1738.0  │ 1.4439e5  │
# │ 5     │ 0.5   │ 4619.0  │ 4.25328e5 │
# │ 6     │ 0.5   │ 4005.0  │ 316661.0  │
# │ 7     │ 0.5   │ 4720.0  │ 3.72266e5 │
# │ 8     │ 0.5   │ 4648.0  │ 2.52338e5 │
# │ 9     │ 0.5   │ 2260.0  │ 194058.0  │
# │ 10    │ 0.5   │ 3915.0  │ 3.15901e5 │
# │ 11    │ 0.5   │ 4568.0  │ 3.53156e5 │
# ⋮
# │ 40720 │ 6.0   │ 14655.0 │ 1260.0    │
# │ 40721 │ 6.0   │ 13264.0 │ 349.0     │
# │ 40722 │ 6.0   │ 12466.0 │ 2897.0    │
# │ 40723 │ 6.0   │ 17747.0 │ 1023.0    │
# │ 40724 │ 6.0   │ 32265.0 │ 615.0     │
# │ 40725 │ 6.0   │ 32403.0 │ 12947.0   │
# │ 40726 │ 6.0   │ 12746.0 │ 3917.0    │
# │ 40727 │ 6.0   │ 61066.0 │ 1092.0    │
# │ 40728 │ 6.0   │ 18921.0 │ 5407.0    │
# ...

# %%
df1 = df[df[:times].==0,:]
df2 = df[df[:times].==1,:]
df3 = df[df[:times].==2,:]
df4 = df[df[:times].==3,:]
df5 = df[df[:times].==4,:]
df6 = df[df[:times].==5,:]
df7 = df[df[:times].==6,:]
df8 = df[df[:times].==7,:]
df9 = df[df[:times].==8,:]
df10 = df[df[:times].==9,:]

p1 = scatter(log10.(df1[:GFP_H]),log10.(df1[:mCherry_H]),yguide="mCherry (a.u.)", xguide="GFP (a.u.)", title="t=0.5hr",xlims=(0,7),ylims=(0,7))
p2 = scatter(log10.(df2[:GFP_H]),log10.(df2[:mCherry_H]),yguide="mCherry (a.u.)", xguide="GFP (a.u.)", title="t=1hr",xlims=(0,7),ylims=(0,7))
p3 = scatter(log10.(df3[:GFP_H]),log10.(df3[:mCherry_H]),yguide="mCherry (a.u.)", xguide="GFP (a.u.)", title="t=2hr",xlims=(0,7),ylims=(0,7))
p4 = scatter(log10.(df4[:GFP_H]),log10.(df4[:mCherry_H]),yguide="mCherry (a.u.)", xguide="GFP (a.u.)", title="t=3hr",xlims=(0,7),ylims=(0,7))
p5 = scatter(log10.(df5[:GFP_H]),log10.(df5[:mCherry_H]),yguide="mCherry (a.u.)", xguide="GFP (a.u.)", title="t=4hr",xlims=(0,7),ylims=(0,7))
p6 = scatter(log10.(df6[:GFP_H]),log10.(df6[:mCherry_H]),yguide="mCherry (a.u.)", xguide="GFP (a.u.)", title="t=5hr",xlims=(0,7),ylims=(0,7))
p7 = scatter(log10.(df7[:GFP_H]),log10.(df7[:mCherry_H]),yguide="mCherry (a.u.)", xguide="GFP (a.u.)", title="t=6hr",xlims=(0,7),ylims=(0,7))
p8 = scatter(log10.(df8[:GFP_H]),log10.(df8[:mCherry_H]),yguide="mCherry (a.u.)", xguide="GFP (a.u.)", title="t=4hr",xlims=(0,7),ylims=(0,7))
p9 = scatter(log10.(df9[:GFP_H]),log10.(df9[:mCherry_H]),yguide="mCherry (a.u.)", xguide="GFP (a.u.)", title="t=5hr",xlims=(0,7),ylims=(0,7))
p10 = scatter(log10.(df10[:GFP_H]),log10.(df10[:mCherry_H]),yguide="mCherry (a.u.)", xguide="GFP (a.u.)", title="t=6hr",xlims=(0,7),ylims=(0,7))
# Out:
# KeyError: key :times not found
#
# Stacktrace:
#  [1] getindex at ./dict.jl:474 [inlined]
#  [2] getindex(::DataFrames.Index, ::Symbol) at /home/jeremy/.julia/v0.6/DataFrames/src/other/index.jl:115
#  [3] getindex(::DataFrames.DataFrame, ::Symbol) at /home/jeremy/.julia/v0.6/DataFrames/src/dataframe/dataframe.jl:228
#  [4] include_string(::String, ::String) at ./loading.jl:522

# %%
using StatPlots
using Measures

# %%
df1 = df[df[:Time].==0.5,:]
df2 = df[df[:Time].==1,:]
df3 = df[df[:Time].==2,:]
df4 = df[df[:Time].==3,:]
df5 = df[df[:Time].==4,:]
df6 = df[df[:Time].==5,:]
df7 = df[df[:Time].==6,:]
p1 = scatter(log10.(df1[:X1]),log10.(df1[:X2]),yguide="mCherry (a.u.)", xguide="GFP (a.u.)", title="t=0.5hr",xlims=(0,7),ylims=(0,7))
p2 = scatter(log10.(df2[:X1]),log10.(df2[:X2]),yguide="mCherry (a.u.)", xguide="GFP (a.u.)", title="t=1hr",xlims=(0,7),ylims=(0,7))
p3 = scatter(log10.(df3[:X1]),log10.(df3[:X2]),yguide="mCherry (a.u.)", xguide="GFP (a.u.)", title="t=2hr",xlims=(0,7),ylims=(0,7))
p4 = scatter(log10.(df4[:X1]),log10.(df4[:X2]),yguide="mCherry (a.u.)", xguide="GFP (a.u.)", title="t=3hr",xlims=(0,7),ylims=(0,7))
p5 = scatter(log10.(df5[:X1]),log10.(df5[:X2]),yguide="mCherry (a.u.)", xguide="GFP (a.u.)", title="t=4hr",xlims=(0,7),ylims=(0,7))
p6 = scatter(log10.(df6[:X1]),log10.(df6[:X2]),yguide="mCherry (a.u.)", xguide="GFP (a.u.)", title="t=5hr",xlims=(0,7),ylims=(0,7))
p7 = scatter(log10.(df7[:X1]),log10.(df7[:X2]),yguide="mCherry (a.u.)", xguide="GFP (a.u.)", title="t=6hr",xlims=(0,7),ylims=(0,7))
# Out:
# <img src="data:image/png;base64,..." />

# %%
f=plot(p1,p2,p3,p4,p5,p6,p7,leg=false,border=:solid,grid=true,size=(800*8,800*8),markersize=0.15,margin=20mm)
savefig(f,"./data.pdf")
f
# Out:
# <img src="data:image/png;base64,..." />

# %%
m1=mean(df1[:X1])./75
m2=mean(df2[:X1])./75
m3=mean(df3[:X1])./75
m4=mean(df4[:X1])./75
m5=mean(df5[:X1])./75
m6=mean(df6[:X1])./75
m7=mean(df7[:X1])./75
# m8=mean(df8[:X2])./75
# m9=mean(df9[:X2])./75
# m10=mean(df10[:X2])./75
mm1=mean(df1[:X2])./100
mm2=mean(df2[:X2])./100
mm3=mean(df3[:X2])./100
mm4=mean(df4[:X2])./100
mm5=mean(df5[:X2])./100
mm6=mean(df6[:X2])./100
mm7=mean(df7[:X2])./100
# mm8=mean(df8[:X3])./100
# mm9=mean(df9[:X3])./100
# mm10=mean(df10[:X3])./100

plot([m1,m2,m3,m4,m5,m6,m7],size=(800*8,800*8))
plot!([mm1,mm2,mm3,mm4,mm5,mm6,mm7],size=(800*8,800*8))
# Out:
# <img src="data:image/png;base64,..." />

# %%
scatter(df9[:X1],df9[:X2],scale=:log10,xlims=(1,10^7),ylims=(1,10^7))
# Out:
# KeyError: key :X1 not found
#
# Stacktrace:
#  [1] getindex at ./dict.jl:474 [inlined]
#  [2] getindex(::DataFrames.Index, ::Symbol) at /home/jeremy/.julia/v0.6/DataFrames/src/other/index.jl:115
#  [3] getindex(::DataFrames.DataFrame, ::Symbol) at /home/jeremy/.julia/v0.6/DataFrames/src/dataframe/dataframe.jl:228
#  [4] include_string(::String, ::String) at ./loading.jl:522

# %%
histogram(log10.(df9[:x2].+1),size=(800*8,800*8))
# Out:
# <img src="data:image/png;base64,..." />

# %%
df = readtable("iptg2")
# Out:
# 40731×3 DataFrames.DataFrame
# │ Row   │ Time │ X1      │ X2        │
# ├───────┼──────┼─────────┼───────────┤
# │ 1     │ 0.5  │ 4308.0  │ 1.76546e5 │
# │ 2     │ 0.5  │ 4840.0  │ 9.54229e5 │
# │ 3     │ 0.5  │ 2118.0  │ 1.14923e5 │
# │ 4     │ 0.5  │ 1738.0  │ 1.4439e5  │
# │ 5     │ 0.5  │ 4619.0  │ 4.25328e5 │
# │ 6     │ 0.5  │ 4005.0  │ 316661.0  │
# │ 7     │ 0.5  │ 4720.0  │ 3.72266e5 │
# │ 8     │ 0.5  │ 4648.0  │ 2.52338e5 │
# │ 9     │ 0.5  │ 2260.0  │ 194058.0  │
# │ 10    │ 0.5  │ 3915.0  │ 3.15901e5 │
# │ 11    │ 0.5  │ 4568.0  │ 3.53156e5 │
# ⋮
# │ 40720 │ 6.0  │ 14655.0 │ 1260.0    │
# │ 40721 │ 6.0  │ 13264.0 │ 349.0     │
# │ 40722 │ 6.0  │ 12466.0 │ 2897.0    │
# │ 40723 │ 6.0  │ 17747.0 │ 1023.0    │
# │ 40724 │ 6.0  │ 32265.0 │ 615.0     │
# │ 40725 │ 6.0  │ 32403.0 │ 12947.0   │
# │ 40726 │ 6.0  │ 12746.0 │ 3917.0    │
# │ 40727 │ 6.0  │ 61066.0 │ 1092.0    │
# │ 40728 │ 6.0  │ 18921.0 │ 5407.0    │
# │ 40729 │ 6.0  │ 15765.0 │ 479.0     │
# ...

# %%
df[:X1]=df[:X1]./75
df[:X2]=df[:X2]./100
# Out:
# 40731-element DataArrays.DataArray{Float64,1}:
#  1765.46
#  9542.29
#  1149.23
#  1443.9
#  4253.28
#  3166.61
#  3722.66
#  2523.38
#  1940.58
#  3159.01
#  3531.56
#  1255.07
#  4356.53
#     ⋮
#    12.6
#     3.49
#    28.97
#    10.23
#     6.15
#   129.47
#    39.17
#    10.92
#    54.07
#     4.79
#     5.96
#     4.16

# %%
writetable("iptg2",df)

# %%
mean(df[df[:Time].==0.5,:][:X1])
# Out:
# 47.08648427572202

# %%
mean(df[df[:Time].==0.5,:][:X2])
# Out:
# 2670.160815811387
